# %%
import os
import json 
import pandas as pd
import mysql.connector as sql

# %%
# Aggregated Transaction

path1 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path1)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path1 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path1)
Agg_state_list

column1 = {'State': [], 'Year': [], 'Quarter': [], 'Transaction_type': [], 'Transaction_count': [],
            'Transaction_amount': []}
for state in Agg_state_list:
    new_state = path1 + state + "/"
    Agg_year_list = os. listdir(new_state)

    for year in Agg_year_list:
        new_year = new_state + year + '/'
        Agg_js_list = os. listdir(new_year)

        for js in Agg_js_list:
            new_js = new_year + js
            data = open(new_js, 'r')
            D = json.load(data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              column1['Transaction_type'].append(Name)
              column1['Transaction_count'].append(count)
              column1['Transaction_amount'].append(amount)
              column1['State'].append(state)
              column1['Year'].append(year)
              column1['Quarter'].append(int(js.strip('.json')))

Agg_tran=pd.DataFrame(column1)

Agg_tran['State'] = Agg_tran['State'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
Agg_tran['State'] = Agg_tran['State'].str.replace("-", " ")
Agg_tran['State'] = Agg_tran['State'].str.title()
Agg_tran['State'] = Agg_tran['State'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu")

Agg_tran
# Out:
#                   State  Year  Quarter          Transaction_type  \
# 0     Andaman & Nicobar  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018        1         Merchant payments
# 3     Andaman & Nicobar  2018        1        Financial Services
# 4     Andaman & Nicobar  2018        1                    Others
# ...                 ...   ...      ...                       ...
# 4489        West Bengal  2024        1         Merchant payments
# 4490        West Bengal  2024        1     Peer-to-peer payments
# 4491        West Bengal  2024        1  Recharge & bill payments
# 4492        West Bengal  2024        1        Financial Services
# 4493        West Bengal  2024        1                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
# Aggregated User 
path2 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/aggregated/user/country/india/state/"
Agg_user_list = os.listdir(path2)
Agg_user_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path2 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/aggregated/user/country/india/state/"
Agg_user_list = os.listdir(path2)
Agg_user_list

column2 = {'State' : [], 'Year' : [], 'Quarter' : [], 'Brands' : [], 'Counts' : [], 'Percentage' : [] }

for state in Agg_user_list:
    new_state = path2 + state + '/'
    Agg_year_list = os.listdir(new_state)
    
    for year in Agg_year_list:
        new_year = new_state + year + '/'
        Agg_js_list = os.listdir(new_year)

        for js in Agg_js_list:
            new_js = new_year + js
            data = open(new_js, 'r')
            D = json.load(data)
            try:
                for z in D['data']['usersByDevice']:
                   brand_name = z['brand']
                   Count = z['count']
                   Percentages = z['percentage']
                   column2['Brands'].append(brand_name)
                   column2['Counts'].append(Count)
                   column2['Percentage'].append(Percentages)
                   column2['State'].append(state)
                   column2['Year'].append(year)
                   column2['Quarter'].append(int(js.strip('.json')))
            except:
                pass

Agg_user=pd.DataFrame(column2)

Agg_user['State'] = Agg_user['State'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
Agg_user['State'] = Agg_user['State'].str.replace("-", " ")
Agg_user['State'] = Agg_user['State'].str.title()
Agg_user['State'] = Agg_user['State'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu")

Agg_user
# Out:
#                   State  Year  Quarter   Brands   Counts  Percentage
# 0     Andaman & Nicobar  2018        1   Xiaomi     1665    0.247033
# 1     Andaman & Nicobar  2018        1  Samsung     1445    0.214392
# 2     Andaman & Nicobar  2018        1     Vivo      982    0.145697
# 3     Andaman & Nicobar  2018        1     Oppo      501    0.074332
# 4     Andaman & Nicobar  2018        1  OnePlus      332    0.049258
# ...                 ...   ...      ...      ...      ...         ...
# 6727        West Bengal  2022        1   Lenovo   330017    0.015056
# 6728        West Bengal  2022        1  Infinix   284678    0.012987
# 6729        West Bengal  2022        1     Asus   280347    0.012790
# 6730        West Bengal  2022        1    Apple   277752    0.012671
# 6731        West Bengal  2022        1   Others  2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
# Map Transaction
path3 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/map/transaction/hover/country/india/state/"
Map_tran_list = os.listdir(path3)
Map_tran_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path3 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/map/transaction/hover/country/india/state/"
Map_tran_list = os.listdir(path3)
Map_tran_list

column3 = {'State': [], 'Year': [], 'Quarter': [], 'District': [], 'Count': [], 'Amount': []}

for state in Map_tran_list:
    new_state = path3 + state + '/'
    Map_year_list = os. listdir(new_state)

    for year in Map_year_list:
        new_year = new_state + year + '/'
        Map_js_list = os. listdir(new_year)

        for js in Map_js_list:
            new_js = new_year + js
            data = open(new_js, 'r')
            D = json.load(data)

            for z in D['data']['hoverDataList']:
                district = z['name']
                Counts = z['metric'][0]['count']
                Amounts = z['metric'][0]['amount']
                column3['Amount'].append(Amounts)
                column3['Count'].append(Counts)
                column3['District'].append(district)
                column3['State'].append(state)
                column3['Year'].append(year)
                column3['Quarter'].append(int(js.strip('.json')))


Map_tran =  pd.DataFrame(column3)

Map_tran['State'] = Map_tran['State'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
Map_tran['State'] = Map_tran['State'].str.replace("-", " ")
Map_tran['State'] = Map_tran['State'].str.title()
Map_tran['State'] = Map_tran['State'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu")

Map_tran
# Out:
#                    State  Year  Quarter                           District  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 18291        West Bengal  2024        1                     nadia district
# 18292        West Bengal  2024        1                   birbhum district
# 18293        West Bengal  2024        1           purba medinipur district
# 18294        West Bengal  2024        1                    maldah district
# 18295        West Bengal  2024        1                 darjiling district
#
#           Count        Amount
# 0           442  9.316631e+05
# ...

# %%
# Map User
path4 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/map/user/hover/country/india/state/"
Map_user_list = os.listdir(path4)
Map_user_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path4 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/map/user/hover/country/india/state/"
Map_user_list = os.listdir(path4)
Map_user_list

column4 = { 'State': [], 'Year': [], 'Quarter': [], 'Registered_Users': [], 'App_Opens': [], 'District': [] }

for state in Map_user_list:
    new_state = path4 + state + '/'
    Map_year_list = os.listdir(new_state)

    for year in Map_year_list:
        new_year = new_state + year + '/'
        Map_js_list = os.listdir(new_year)

        for js in Map_js_list:
            new_js = new_year + js
            data = open(new_js, 'r')
            D = json.load(data)
            for z in D['data']['hoverData'].items():
                        district = z[0]
                        reg_users = z[1]['registeredUsers']
                        app_opens = z[1]['appOpens']
                        column4['App_Opens'].append(app_opens)
                        column4['District'].append(district)
                        column4['Registered_Users'].append(reg_users)
                        column4['State'].append(state)
                        column4['Year'].append(year)
                        column4['Quarter'].append(int(js.strip('.json')))

Map_user = pd.DataFrame(column4)

Map_user['State'] = Map_user['State'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
Map_user['State'] = Map_user['State'].str.replace("-", " ")
Map_user['State'] = Map_user['State'].str.title()
Map_user['State'] = Map_user['State'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu")

Map_user
# Out:
#                    State  Year  Quarter  Registered_Users  App_Opens  \
# 0      Andaman & Nicobar  2018        1               632          0
# 1      Andaman & Nicobar  2018        1              5846          0
# 2      Andaman & Nicobar  2018        1               262          0
# 3      Andaman & Nicobar  2018        2               911          0
# 4      Andaman & Nicobar  2018        2              8143          0
# ...                  ...   ...      ...               ...        ...
# 18295        West Bengal  2024        1           1671140   13679202
# 18296        West Bengal  2024        1           1056537   30502875
# 18297        West Bengal  2024        1           1655920   18688405
# 18298        West Bengal  2024        1           1183956   33270738
# 18299        West Bengal  2024        1            686254   31485682
#
#                                 District
# 0      north and middle andaman district
# 1                 south andaman district
# ...

# %%
# Top Transaction
path5 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/top/transaction/country/india/state/"
Top_Tran_list = os.listdir(path5)
Top_Tran_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path5 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/top/transaction/country/india/state/"
Top_Tran_list = os.listdir(path5)
Top_Tran_list

column5 = {'State': [], 'Year': [], 'Quater': [], 'District': [], 'Transaction_Count': [], 'Transaction_Amount': []}


for state in Top_Tran_list:
    new_state = path5 + state + '/'
    Top_year_list = os.listdir(new_state)

    for year in Top_year_list:
        new_year = new_state + year + '/'
        Top_js_list = os.listdir(new_year)

        for js in Top_js_list:
            new_js = new_year + js 
            data = open(new_js, 'r')
            D = json.load(data)
            for z in D['data']['districts']:
                Name = z['entityName']
                Counts = z['metric']['count']
                Amounts = z['metric']['amount']
                column5['State'].append(state)
                column5['Year'].append(year)
                column5['District'].append(Name)
                column5['Transaction_Count'].append(Counts)
                column5['Transaction_Amount'].append(Amounts)
                column5['Quater'].append(int(js.strip('.json')))


Top_tran = pd.DataFrame(column5)

Top_tran['State'] = Top_tran['State'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
Top_tran['State'] = Top_tran['State'].str.replace("-", " ")
Top_tran['State'] = Top_tran['State'].str.title()
Top_tran['State'] = Top_tran['State'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu")

Top_tran
# Out:
#                   State  Year  Quater                  District  \
# 0     Andaman & Nicobar  2018       1             south andaman
# 1     Andaman & Nicobar  2018       1                  nicobars
# 2     Andaman & Nicobar  2018       1  north and middle andaman
# 3     Andaman & Nicobar  2018       2             south andaman
# 4     Andaman & Nicobar  2018       2                  nicobars
# ...                 ...   ...     ...                       ...
# 7395        West Bengal  2024       1                    maldah
# 7396        West Bengal  2024       1                     nadia
# 7397        West Bengal  2024       1                    howrah
# 7398        West Bengal  2024       1                   hooghly
# 7399        West Bengal  2024       1         paschim medinipur
#
#       Transaction_Count  Transaction_Amount
# 0                  5688        1.256025e+07
# 1                   528        1.139849e+06
# 2                   442        9.316631e+05
# ...

# %%
# Top User
path6 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/top/user/country/india/state/"
Top_User_list = os.listdir(path6)
Top_User_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
path6 = "C:/Users/Bala Krishnan/OneDrive/Desktop/data/pulse/data/top/user/country/india/state/"
Top_User_list = os.listdir(path6)
Top_User_list

column6 = {'State': [], 'Year': [], 'Quater': [], 'District': [], 'Registered_Users': []}

for state in Top_User_list:
    new_state = path6 + state + '/'
    Top_year_list = os.listdir(new_state)

    for year in Top_year_list:
        new_year = new_state + year + '/'
        Top_js_list = os.listdir(new_year)

        for js in Top_js_list:
            new_js = new_year + js
            data = open(new_js, 'r')
            D = json.load(data)
            for z in D['data']['districts']:
                Name_st = z['name']
                Reg_user = z['registeredUsers']
                column6['State'].append(state)
                column6['Year'].append(year)
                column6['District'].append(Name_st)
                column6['Registered_Users'].append(Reg_user)
                column6['Quater'].append(int(js. strip('.json')))

Top_user = pd.DataFrame(column6)

Top_user['State'] = Top_user['State'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
Top_user['State'] = Top_user['State'].str.replace("-", " ")
Top_user['State'] = Top_user['State'].str.title()
Top_user['State'] = Top_user['State'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu")

Top_user
# Out:
#                   State  Year  Quater                  District  \
# 0     Andaman & Nicobar  2018       1             south andaman
# 1     Andaman & Nicobar  2018       1  north and middle andaman
# 2     Andaman & Nicobar  2018       1                  nicobars
# 3     Andaman & Nicobar  2018       2             south andaman
# 4     Andaman & Nicobar  2018       2  north and middle andaman
# ...                 ...   ...     ...                       ...
# 7395        West Bengal  2024       1                    howrah
# 7396        West Bengal  2024       1                     nadia
# 7397        West Bengal  2024       1           purba medinipur
# 7398        West Bengal  2024       1         paschim medinipur
# 7399        West Bengal  2024       1           purba bardhaman
#
#       Registered_Users
# 0                 5846
# 1                  632
# 2                  262
# 3                 8143
# 4                  911
# ...                ...
# 7395           1737851
# ...

# %%
# Convert DataFrame to CSV File 
Agg_tran.to_csv('Agg_tran_path1.csv')
Agg_user.to_csv('Agg_user_path2.csv')
Map_tran.to_csv('Map_tran_path3.csv')
Map_user.to_csv('Map_user_path4.csv')
Top_tran.to_csv('Top_tran_path5.csv')
Top_user.to_csv('Top_user_path6.csv')

# %%
unique_brands = Agg_user['Brands'].unique()
unique_brands
# Out:
# array(['Xiaomi', 'Samsung', 'Vivo', 'Oppo', 'OnePlus', 'Realme', 'Apple',
#        'Motorola', 'Lenovo', 'Huawei', 'Others', 'Tecno', 'Gionee',
#        'Infinix', 'Asus', 'Micromax', 'HMD Global', 'Lava', 'COOLPAD',
#        'Lyf'], dtype=object)

# %%
mysql = sql.connect(
    host = "localhost",
    user= "root",
    password = "mysqlroot",
    database ="PhonePe"
  )
cursor = mysql.cursor()

# %%
# Create table for Aggregated Transaction 01
query = "create table if not exists Aggregated_Transaction (State varchar(100), Year int, Quarter int, Transaction_type varchar(300), Transaction_count bigint, Transaction_amount float)"
cursor.execute(query)
mysql.commit()
insertquery = "insert into Aggregated_Transaction (State, Year, Quarter, Transaction_type, Transaction_count, Transaction_amount) values (%s,%s,%s,%s,%s,%s)"
values = Agg_tran.values.tolist()
cursor.executemany(insertquery, values)
mysql.commit()

# %%
# Create table for Aggregated User 02
query = "create table if not exists Aggregated_User (State varchar(100), Year int, Quarter int, Brands varchar(300), Counts bigint, Percentage float) "
cursor.execute(query)
mysql.commit()
insertquery = "insert into Aggregated_User (State, Year, Quarter, Brands, Counts, Percentage) values(%s,%s,%s,%s,%s,%s)"
values = Agg_user.values.tolist()
cursor.executemany(insertquery, values)
mysql.commit()

# %%
# Create table for Map Transaction 03
query = "create table if not exists Map_Transaction (State varchar(100), Year int, Quarter int, District varchar(100), Count bigint, Amount float)"
cursor.execute(query)
mysql.commit()
insertquery = "insert into Map_Transaction (State, Year, Quarter, District, Count, Amount) values(%s,%s,%s,%s,%s,%s)"
values = Map_tran.values.tolist()
cursor.executemany(insertquery, values)
mysql.commit()

# %%
# Create table for Map User 04
query = "create table if not exists Map_user (State varchar(100), Year int, Quarter int, Registered_Users bigint, App_Opens bigint, District varchar(100))"
cursor.execute(query)
mysql.commit()
insertquery = "insert into Map_user (State, Year, Quarter, Registered_Users, App_Opens, District) values (%s,%s,%s,%s,%s,%s)"
values = Map_user.values.tolist()
cursor.executemany(insertquery, values)
mysql.commit()

# %%
# Create table for Top Transaction 05
query = "create table if not exists Top_Transaction (State varchar(100), Year int, Quater int, District varchar(100), Transaction_Count bigint, Transaction_Amount float)"
cursor.execute(query)
mysql.commit()
insertquery = "insert into Top_Transaction (State, Year, Quater, District, Transaction_Count, Transaction_Amount) values (%s,%s,%s,%s,%s,%s)"
values = Top_tran.values.tolist()
cursor.executemany(insertquery, values)
mysql.commit()

# %%
# Create table for Top_User 06
query = "Create table if not exists Top_User (State varchar(100), Year int, Quater int, District varchar(100), Registered_Users bigint)"
cursor.execute(query)
mysql.commit()
insertquery = "insert into Top_User (State, Year, Quater, District, Registered_Users) values (%s,%s,%s,%s,%s)"
values = Top_user.values.tolist()
cursor.executemany(insertquery, values)
mysql.commit()

# %%
# Aggregated_transaction
cursor.execute("SELECT * FROM phonepe.aggregated_transaction;")
df = pd.DataFrame(cursor.fetchall(),columns = cursor.column_names)
st.write(df)

# Aggregated_user
cursor.execute("SELECT * FROM phonepe.aggregated_user;")
df = pd.DataFrame(cursor.fetchall(),columns = cursor.column_names)
st.write(df)

# Map_transaction
cursor.execute("SELECT * FROM phonepe.map_transaction;")
df = pd.DataFrame(cursor.fetchall(),columns = cursor.column_names)
st.write(df)

# Map_user
cursor.execute("SELECT * FROM phonepe.map_user;")
df = pd.DataFrame(cursor.fetchall(),columns = cursor.column_names)
st.write(df)

# Top_transaction
cursor.execute("SELECT * FROM phonepe.top_transaction;")
df = pd.DataFrame(cursor.fetchall(),columns = cursor.column_names)
st.write(df)

# Top_user
cursor.execute("SELECT * FROM phonepe.top_user;")
df = pd.DataFrame(cursor.fetchall(),columns = cursor.column_names)
st.write(df)

# %%
cursor.execute(f"SELECT State, SUM(Transaction_count) AS Total_Transactions, SUM(Transaction_amount) AS Total_Amount FROM phonepe.aggregated_transaction WHERE Year = {Years} AND Quarter = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Transactions', 'Total_Amount'])
        df2 = pd.read_csv("https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/active_cases_2020-07-17_0800.csv")
        #df1.State = df2
        #df1 = df1.merge(df2, on='State')

        fig = px.choropleth(df2,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='state',
                    color='active cases',
                    color_continuous_scale='Reds')

        fig.update_geos(fitbounds="locations", visible=False)
        #fig.update_layout(title_font=dict(size=33), title_font_color='#6739b7', height=800)
        #st.plotly_chart(fig,use_container_width=True)
        fig.show()

# %%
st.header(" :violet[ Overall State Transactions Amount]")
        cursor.execute(f"SELECT State, SUM(Transaction_count) AS Total_Transactions, SUM(Transaction_amount) AS Total_Amount FROM phonepe.aggregated_transaction WHERE Year = {Years} AND Quarter = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Transactions', 'Total_Amount'])
        df2 = pd.read_csv('Agg_tran_path1.csv')
        df3 = df1.merge(df2, on='State')
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='State',
                    color='Total_Amount',
                    color_continuous_scale='haline')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)
        fig.show()

     
        #with col2:
    if Transaction == "Count":

        st.header(" :violet[ Overall State Transactions Count]")
        cursor.execute(f"SELECT State, SUM(Transaction_count) AS Total_Transactions, SUM(Transaction_amount) AS Total_Amount FROM phonepe.aggregated_transaction WHERE Year = {Years} AND Quarter = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Transactions', 'Total_Amount'])
        df2 = pd.read_csv('Agg_tran_path1.csv')
        df3 = df1.merge(df2, on='State')
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='State',
                    color='Total_Transactions',
                    color_continuous_scale='Rainbow')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)
        fig.show()

# %%
# Count

st.header(" :violet[ Overall State Map Transactions Count]")
        cursor.execute(f"SELECT State, SUM(Count) AS Total_Count FROM phonepe.map_transaction WHERE Year = {Years} AND Quarter = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Count'])
        df2 = pd.read_csv('Map_tran_path3.csv')
        df3 = df1.merge(df2, on='State')
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='State',
                    color='Total_Count',
                    color_continuous_scale='amp')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)
        fig.show()


        st.header(" :violet[ Overall State Top Transactions Count]")
        cursor.execute(f"SELECT State, SUM(Transaction_Count) AS Total_Count FROM  phonepe.top_transaction WHERE Year = {Years} AND Quater = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Count'])
        df2 = pd.read_csv('Top_tran_path5.csv')
        df3 = df1.merge(df2, on='State')
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='State',
                    color='Total_Count',
                    color_continuous_scale='Green')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)
        fig.show()

# %%
# Amount

st.header(" :violet[ Overall State Map Transactions Amount]")
        cursor.execute(f"SELECT State, SUM(Amount) AS Total_Amount FROM phonepe.map_transaction WHERE Year = {Years} AND Quarter = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Amount'])
        df2 = pd.read_csv('Map_tran_path3.csv')
        df3 = df1.merge(df2, on='State')
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='State',
                    color='Total_Amount',
                    color_continuous_scale='Reds')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)
        fig.show()


        st.header(" :violet[ Overall State Top Transactions Amount]")
        cursor.execute(f"SELECT State, SUM(Transaction_Amount) AS Total_Amount FROM  phonepe.top_transaction WHERE Year = {Years} AND Quater = {Quarter} GROUP BY State ORDER BY State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Amount'])
        df2 = pd.read_csv('Top_tran_path5.csv')
        df3 = df1.merge(df2, on='State')
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                    featureidkey='properties.ST_NM',
                    locations='State',
                    color='Total_Amount',
                    color_continuous_scale='Blues')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)
        fig.show()

# %%
# Mobile Brands

with col3:
            Brands_type = st.selectbox('**Select Mobile Brand type**',
                                        ('Xiaomi', 'Samsung', 'Vivo', 'Oppo', 'OnePlus', 'Realme', 'Apple',
                                         'Motorola', 'Lenovo', 'Huawei', 'Others', 'Tecno', 'Gionee',
                                         'Infinix', 'Asus', 'Micromax', 'HMD Global', 'Lava', 'COOLPAD','Lyf'), key='Brands_type')


st.markdown("## :violet[Overall State Users Mobile Brands]")
        cursor.execute(f"select State, sum(Counts) as Total_Counts from phonepe.aggregated_user where Year = {Years} and Quarter = {Quarter} and Brands = '{Brands_type}' group by State order by State;")
        df1 = pd.DataFrame(cursor.fetchall(), columns=['State', 'Total_Counts'])
        df2 = pd.read_csv('Agg_user_path2.csv')
        df3 = df1.merge(df2, on='State')            
        fig = px.choropleth(df1,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                featureidkey='properties.ST_NM',
                locations='State',
                color='Total_Counts',
                color_continuous_scale='Reds')

        fig.update_geos(fitbounds="locations", visible=False)
        st.plotly_chart(fig,use_container_width=True)

# %%
 st.markdown("## :violet[Overall State Registered Users]")
        query = (f"select State, sum(Registered_Users) as Total_Users, avg(Registered_Users) as 'Average Transaction Amount' FROM phonepe.top_user where Year = {Years} and Quater = {Quarter} group by State;")
        cursor.execute(query)
        results = cursor.fetchall()
        df = pd.DataFrame(results, columns=['State', 'Total_Users', 'Average Transaction Amount'])

        fig = px.choropleth_mapbox(df,geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
                                    featureidkey='properties.ST_NM',
                                    locations='State',
                                    hover_data=['Total_Users', 'Average Transaction Amount'],
                                    color='Total_Users',
                                    color_continuous_scale=px.colors.sequential.matter_r,
                                    mapbox_style="carto-positron",zoom=3.5,
                                    center={"lat": 21.7679, "lon": 78.8718})
        fig.update_geos(fitbounds="locations", visible=False)
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        fig.update_layout(height=600)

# %%
col1,col2=st.columns(2)
    with col1:
                st.subheader(':violet[What is Phonepe?]')
                st.markdown('''<h5>PhonePe is a popular digital payments platform in India, offering a range of financial services through its mobile app.
                        Users can make payments, transfer money, recharge phones, pay bills, invest, shop online, and more.<p>
                        <h5>PhonePe has become a preferred choice for millions of users, contributing to India's digital payments revolution.<h5>''',unsafe_allow_html=True)
                
                st.subheader(':violet[what is Phonepe Pulse?]')
                st.markdown('''<h5>PhonePe Pulse provides real-time insights and trends on digital payments across India.
                Its offers comprehensive analytics including transaction volumes, consumer demographics, popular merchant categories,
                geographic trends, transaction values, payment methods, and seasonal fluctuations.<h5>''',unsafe_allow_html=True)
    with col2:
                st.markdown("![Alt Text](https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExY2Vvb2oyaHBqNHZzdm9ycG5lcDEyczk3dDZtcnplamdpbGJudG8xNiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/gSU4qpRY00OOe6v8I8/giphy-downsized-large.gif)")

    col1,col2=st.columns(2)
    with col1:
                st.image('https://www.phonepe.com/pulsestatic/791/pulse/static/4cb2e7589c30e73dca3d569aea9ca280/1b2a8/pulse-2.webp',use_column_width=True)
    with col2:
                st.write(' ')
                st.subheader(':violet[Discover Insights:]')
                st.markdown('''
                        <h4>Transaction:<h5>Transaction insights involve analyzing customer transaction data to understand behavior and preferences.
                        By examining trends, categorizing transactions,and identifying patterns of india.
                        <h4>User: <h5>User insights refer to analyzing customer demographics, engagement metrics, and feedback.
                        By understanding demographics, tracking engagement of user in India ''',unsafe_allow_html=True)
                
                st.subheader(':violet[This Project is Inspired From Phonepe pulse]')
                st.link_button('Go to Phonepe Pulse','https://www.phonepe.com/pulse/')

    st.subheader(':violet[More About Phonepe Pulse]')
    col1,col2=st.columns(2)
    with col1:
                st.video('https://youtu.be/c_1H6vivsiA?si=lVPODg0axykJgeAZ')
    with col2:
                st.video('https://youtu.be/Yy03rjSUIB8?si=eJRqbCm-K_RDtv0Y')
